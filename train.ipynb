# %%
import paddle
print("paddle:", paddle.__version__)
print("cuda available:", paddle.is_compiled_with_cuda())
print("device:", paddle.device.get_device())
# Out:
# /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages/paddle/utils/cpp_extension/extension_utils.py:718: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# paddle: 3.2.2
# cuda available: True
# device: gpu:0

# %%
from pathlib import Path

DATA_DIR = Path("train_data/rec")
TRAIN_GT = DATA_DIR / "rec_gt_train.txt"
VAL_GT   = DATA_DIR / "rec_gt_val.txt"

assert TRAIN_GT.exists() and VAL_GT.exists(), "ไม่เจอ rec_gt_train/val.txt"
assert (DATA_DIR/"train").exists() and (DATA_DIR/"val").exists(), "ไม่เจอโฟลเดอร์ train/val"

def read_gt(p):
    lines = p.read_text(encoding="utf-8").splitlines()
    pairs = []
    for i, line in enumerate(lines[:]):
        if "\t" not in line:
            raise ValueError(f"บรรทัดที่ {i} ไม่มี TAB (\\t): {line[:120]}")
        img_rel, text = line.split("\t", 1)
        img_path = DATA_DIR / img_rel
        if not img_path.exists():
            raise FileNotFoundError(f"ไม่เจอรูป: {img_path}")
        pairs.append((img_rel, text))
    return pairs

train_pairs = read_gt(TRAIN_GT)
val_pairs = read_gt(VAL_GT)

print("train lines:", len(train_pairs))
print("val lines:", len(val_pairs))
print("sample:", train_pairs[0])

# สร้าง dict จากข้อความทั้งหมด (ตัด space ออก แล้วใช้ use_space_char=True ตอนเทรน)
chars = set()
max_len = 0
for _, t in train_pairs + val_pairs:
    max_len = max(max_len, len(t))
    for ch in t:
        if ch != " ":
            chars.add(ch)

DICT_PATH = DATA_DIR / "dict_custom.txt"
DICT_PATH.write_text("".join([c + "\n" for c in sorted(chars, key=lambda x: ord(x))]), encoding="utf-8")

print("dict saved:", DICT_PATH)
print("charset_size:", len(chars))
print("max_text_length in labels:", max_len)
# Out:
# train lines: 50
# val lines: 128
# sample: ('train/train_000000.jpg', 'TOTAL ฿ 1,234.50')
# dict saved: train_data/rec/dict_custom.txt
# charset_size: 109
# max_text_length in labels: 84

# %%
import yaml
from pathlib import Path

PRETRAIN = Path("pretrain_models/th_PP-OCRv5_mobile_rec_pretrained.pdparams")
assert PRETRAIN.exists(), f"ไม่เจอไฟล์ pretrained: {PRETRAIN}"

# หา config ไทยอัตโนมัติ (กัน path ไม่ตรงเวอร์ชัน)
candidates = list(Path("configs").rglob("th_PP-OCRv5_mobile_rec*.y*ml"))
assert candidates, "หา config th_PP-OCRv5_mobile_rec ไม่เจอใน configs/"
BASE_CFG = candidates[0]
print("base config:", BASE_CFG)

cfg = yaml.safe_load(BASE_CFG.read_text(encoding="utf-8"))

# ---------- Global ----------
cfg.setdefault("Global", {})
cfg["Global"]["pretrained_model"] = str(PRETRAIN)
cfg["Global"]["save_model_dir"] = "./output/th_rec_finetune"
cfg["Global"]["epoch_num"] = 20
cfg["Global"]["use_space_char"] = True
# cfg["Global"]["character_dict_path"] = str(DICT_PATH)   # ใช้ dict ที่สร้างจาก label
cfg["Global"]["print_batch_step"] = 50

# ถ้า label ยาวกว่าค่าเดิมมาก ๆ ให้ปรับ max_text_length
# (บาง config เก็บใน Train/Eval transforms แต่หลายอันอยู่ใน Global/หรือ PostProcess)
# ใส่ไว้ใน Global เผื่อ config รองรับ:
cfg["Global"]["max_text_length"] = int(max_len) + 5
cfg["Global"]["use_gpu"] = True
# ---------- Dataset paths ----------
cfg.setdefault("Train", {}).setdefault("dataset", {})
cfg["Train"]["dataset"]["data_dir"] = "./train_data/rec"
cfg["Train"]["dataset"]["label_file_list"] = ["./train_data/rec/rec_gt_train.txt"]

cfg.setdefault("Eval", {}).setdefault("dataset", {})
cfg["Eval"]["dataset"]["data_dir"] = "./train_data/rec"
cfg["Eval"]["dataset"]["label_file_list"] = ["./train_data/rec/rec_gt_val.txt"]
cfg["Eval"]["loader"]["batch_size_per_card"] = 1

# ---------- Learning rate (fine-tune แนะนำลด LR) ----------
cfg.setdefault("Optimizer", {}).setdefault("lr", {})
if isinstance(cfg["Optimizer"]["lr"], dict):
    cfg["Optimizer"]["lr"]["learning_rate"] = 1e-4

OUT_CFG = Path("configs/rec/my_th_rec_finetune.yaml")
OUT_CFG.parent.mkdir(parents=True, exist_ok=True)
OUT_CFG.write_text(yaml.safe_dump(cfg, sort_keys=False, allow_unicode=True), encoding="utf-8")
print("saved:", OUT_CFG)
# Out:
# base config: configs/rec/PP-OCRv5/multi_language/th_PP-OCRv5_mobile_rec.yaml
# saved: configs/rec/my_th_rec_finetune.yaml

# %%
import os, sys, subprocess


cmd = [sys.executable, "-m", "paddle.distributed.launch", "tools/train.py",
       "-c", "configs/rec/my_th_rec_finetune.yaml"]
p = subprocess.run(cmd, text=True, capture_output=True)

print("returncode =", p.returncode)
print("\n===== STDOUT (tail) =====")
print(p.stdout[-4000:])
print("\n===== STDERR (tail) =====")
print(p.stderr[-4000:])
# Out:
# returncode = 0
#
# ===== STDOUT (tail) =====
# 34 MB
# [2025/12/17 10:27:07] ppocr INFO: save model in ./output/th_rec_finetune/latest
# [2025/12/17 10:27:12] ppocr INFO: epoch: [13/20], global_step: 39, lr: 0.000088, acc: 0.120000, norm_edit_dis: 0.668568, CTCLoss: 19.720331, NRTRLoss: 1.145633, loss: 20.867764, avg_reader_cost: 0.03702 s, avg_batch_cost: 0.11233 s, avg_samples: 4.0, ips: 35.61085 samples/s, eta: 0:00:39, max_mem_reserved: 13529 MB, max_mem_allocated: 13234 MB
# [2025/12/17 10:27:13] ppocr INFO: save model in ./output/th_rec_finetune/latest
# [2025/12/17 10:27:18] ppocr INFO: epoch: [14/20], global_step: 42, lr: 0.000082, acc: 0.120000, norm_edit_dis: 0.669518, CTCLoss: 18.214540, NRTRLoss: 1.128917, loss: 19.333504, avg_reader_cost: 0.04475 s, avg_batch_cost: 0.12087 s, avg_samples: 4.0, ips: 33.09323 samples/s, eta: 0:00:34, max_mem_reserved: 13529 MB, max_mem_allocated: 13234 MB
# [2025/12/17 10:27:19] ppocr INFO: save model in ./output/th_rec_finetune/latest
# [2025/12/17 10:27:23] ppocr INFO: epoch: [15/20], global_step: 45, lr: 0.000076, acc: 0.120000, norm_edit_dis: 0.667166, CTCLoss: 16.786375, NRTRLoss: 1.124486, loss: 17.900572, avg_reader_cost: 0.03723 s, avg_batch_cost: 0.11320 s, avg_samples: 4.0, ips: 35.33564 samples/s, eta: 0:00:28, max_mem_reserved: 13529 MB, max_mem_allocated: 13234 MB
# [2025/12/17 10:27:24] ppocr INFO: save model in ./output/th_rec_finetune/latest
# [2025/12/17 10:27:30] ppocr INFO: epoch: [16/20], global_step: 48, lr: 0.000069, acc: 0.140000, norm_edit_dis: 0.670897, CTCLoss: 15.591711, NRTRLoss: 1.106037, loss: 16.665677, avg_reader_cost: 0.04737 s, avg_batch_cost: 0.12364 s, avg_samples: 4.0, ips: 32.35246 samples/s, eta: 0:00:23, max_mem_reserved: 13529 MB, max_mem_allocated: 13234 MB
# [2025/12/17 10:27:31] ppocr INFO: save model in ./output/th_rec_finetune/latest
# [2025/12/17 10:27:34] ppocr INFO: epoch: [17/20], global_step: 50, lr: 0.000064, acc: 0.160000, norm_edit_dis: 0.671965, CTCLoss: 14.982632, NRTRLoss: 1.101842, loss: 16.080804, avg_reader_cost: 0.03275 s, avg_batch_cost: 0.08035 s, avg_samples: 2.0, ips: 24.89062 samples/s, eta: 0:00:19, max_mem_reserved: 13529 MB, max_mem_allocated: 13234 MB
# [2025/12/17 10:27:35] ppocr INFO: epoch: [17/20], global_step: 51, lr: 0.000062, acc: 0.140000, norm_edit_dis: 0.667957, CTCLoss: 15.511082, NRTRLoss: 1.101842, loss: 16.582536, avg_reader_cost: 0.00006 s, avg_batch_cost: 0.02876 s, avg_samples: 2.0, ips: 69.53421 samples/s, eta: 0:00:17, max_mem_reserved: 13529 MB, max_mem_allocated: 13234 MB
# [2025/12/17 10:27:36] ppocr INFO: save model in ./output/th_rec_finetune/latest
# [2025/12/17 10:27:41] ppocr INFO: epoch: [18/20], global_step: 54, lr: 0.000054, acc: 0.160000, norm_edit_dis: 0.673279, CTCLoss: 14.460680, NRTRLoss: 1.091859, loss: 15.532010, avg_reader_cost: 0.04688 s, avg_batch_cost: 0.12242 s, avg_samples: 4.0, ips: 32.67537 samples/s, eta: 0:00:11, max_mem_reserved: 13529 MB, max_mem_allocated: 13234 MB
# [2025/12/17 10:27:42] ppocr INFO: save model in ./output/th_rec_finetune/latest
# [2025/12/17 10:27:47] ppocr INFO: epoch: [19/20], global_step: 57, lr: 0.000046, acc: 0.180000, norm_edit_dis: 0.676095, CTCLoss: 14.889705, NRTRLoss: 1.087547, loss: 15.943060, avg_reader_cost: 0.03834 s, avg_batch_cost: 0.11387 s, avg_samples: 4.0, ips: 35.12663 samples/s, eta: 0:00:05, max_mem_reserved: 13529 MB, max_mem_allocated: 13234 MB
# [2025/12/17 10:27:48] ppocr INFO: save model in ./output/th_rec_finetune/latest
# [2025/12/17 10:27:53] ppocr INFO: epoch: [20/20], global_step: 60, lr: 0.000038, acc: 0.180000, norm_edit_dis: 0.676095, CTCLoss: 14.518790, NRTRLoss: 1.080885, loss: 15.568244, avg_reader_cost: 0.04300 s, avg_batch_cost: 0.11867 s, avg_samples: 4.0, ips: 33.70597 samples/s, eta: 0:00:00, max_mem_reserved: 13529 MB, max_mem_allocated: 13234 MB
# [2025/12/17 10:27:54] ppocr INFO: save model in ./output/th_rec_finetune/latest
# [2025/12/17 10:27:54] ppocr INFO: save model in ./output/th_rec_finetune/iter_epoch_20
# [2025/12/17 10:27:54] ppocr INFO: best metric, acc: 0, is_float16: False
#
#
# ===== STDERR (tail) =====
# /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages/paddle/utils/cpp_extension/extension_utils.py:718: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# LAUNCH INFO 2025-12-17 10:25:54,152 -----------  Configuration  ----------------------
# LAUNCH INFO 2025-12-17 10:25:54,152 auto_cluster_config: 0
# LAUNCH INFO 2025-12-17 10:25:54,152 auto_parallel_config: None
# LAUNCH INFO 2025-12-17 10:25:54,152 auto_tuner_json: None
# LAUNCH INFO 2025-12-17 10:25:54,152 devices: None
# LAUNCH INFO 2025-12-17 10:25:54,152 elastic_level: -1
# LAUNCH INFO 2025-12-17 10:25:54,152 elastic_timeout: 30
# LAUNCH INFO 2025-12-17 10:25:54,152 enable_gpu_log: True
# LAUNCH INFO 2025-12-17 10:25:54,152 gloo_port: 6767
# LAUNCH INFO 2025-12-17 10:25:54,153 host: None
# LAUNCH INFO 2025-12-17 10:25:54,153 ips: None
# LAUNCH INFO 2025-12-17 10:25:54,153 job_id: default
# LAUNCH INFO 2025-12-17 10:25:54,153 legacy: False
# LAUNCH INFO 2025-12-17 10:25:54,153 log_dir: log
# LAUNCH INFO 2025-12-17 10:25:54,153 log_level: INFO
# LAUNCH INFO 2025-12-17 10:25:54,153 log_overwrite: False
# LAUNCH INFO 2025-12-17 10:25:54,153 master: None
# LAUNCH INFO 2025-12-17 10:25:54,153 max_restart: 3
# LAUNCH INFO 2025-12-17 10:25:54,153 nnodes: 1
# LAUNCH INFO 2025-12-17 10:25:54,153 nproc_per_node: None
# LAUNCH INFO 2025-12-17 10:25:54,153 rank: -1
# LAUNCH INFO 2025-12-17 10:25:54,153 run_mode: collective
# LAUNCH INFO 2025-12-17 10:25:54,153 server_num: None
# LAUNCH INFO 2025-12-17 10:25:54,153 servers:
# LAUNCH INFO 2025-12-17 10:25:54,153 sort_ip: False
# LAUNCH INFO 2025-12-17 10:25:54,153 start_port: 6070
# LAUNCH INFO 2025-12-17 10:25:54,153 trainer_num: None
# LAUNCH INFO 2025-12-17 10:25:54,153 trainers:
# LAUNCH INFO 2025-12-17 10:25:54,153 training_script: tools/train.py
# LAUNCH INFO 2025-12-17 10:25:54,153 training_script_args: ['-c', 'configs/rec/my_th_rec_finetune.yaml']
# LAUNCH INFO 2025-12-17 10:25:54,153 with_gloo: 1
# LAUNCH INFO 2025-12-17 10:25:54,153 --------------------------------------------------
# LAUNCH INFO 2025-12-17 10:25:54,154 Job: default, mode collective, replicas 1[1:1], elastic False
# LAUNCH INFO 2025-12-17 10:25:54,155 Run Pod: bohrul, replicas 1, status ready
# LAUNCH INFO 2025-12-17 10:25:54,168 Watching Pod: bohrul, replicas 1, status running
# LAUNCH INFO 2025-12-17 10:27:56,190 Pod completed
# LAUNCH INFO 2025-12-17 10:27:56,190 Exit code 0

# %%
from pathlib import Path
import yaml

cfg = yaml.safe_load(Path("configs/rec/my_th_rec_finetune.yaml").read_text(encoding="utf-8"))
dict_path = Path(cfg["Global"]["character_dict_path"])
use_space = cfg["Global"].get("use_space_char", False)

n_lines = len(dict_path.read_text(encoding="utf-8").splitlines())
print("dict_path:", dict_path)
print("dict lines:", n_lines)
print("use_space_char:", use_space)
print("effective charset size (incl space if enabled):", n_lines + (1 if use_space else 0))
# Out:
# dict_path: ppocr/utils/dict/ppocrv5_th_dict.txt
# dict lines: 524
# use_space_char: True
# effective charset size (incl space if enabled): 525

# %%
import sys, subprocess
best = "./output/th_rec_finetune/iter_epoch_20.pdparams"
cmd = [sys.executable, "tools/eval.py", "-c", "configs/rec/my_th_rec_finetune.yaml",
       "-o", f"Global.pretrained_model={best}"]
with open("output/th_rec_finetune/eval.log", "w", encoding="utf-8") as f:
    subprocess.run(cmd, stdout=f, stderr=subprocess.STDOUT, text=True, check=True)
p = subprocess.run(cmd, text=True, capture_output=True)

print("returncode =", p.returncode)
print("\n===== STDOUT (tail) =====")
print(p.stdout[-4000:])
print("\n===== STDERR (tail) =====")
print(p.stderr[-4000:])
# Out:
# returncode = 0
#
# ===== STDOUT (tail) =====
# 5/12/17 10:29:13] ppocr INFO:     loss_config_list :
# [2025/12/17 10:29:13] ppocr INFO:         CTCLoss : None
# [2025/12/17 10:29:13] ppocr INFO:         NRTRLoss : None
# [2025/12/17 10:29:13] ppocr INFO:     name : MultiLoss
# [2025/12/17 10:29:13] ppocr INFO: Metric :
# [2025/12/17 10:29:13] ppocr INFO:     ignore_space : False
# [2025/12/17 10:29:13] ppocr INFO:     main_indicator : acc
# [2025/12/17 10:29:13] ppocr INFO:     name : RecMetric
# [2025/12/17 10:29:13] ppocr INFO: Optimizer :
# [2025/12/17 10:29:13] ppocr INFO:     beta1 : 0.9
# [2025/12/17 10:29:13] ppocr INFO:     beta2 : 0.999
# [2025/12/17 10:29:13] ppocr INFO:     lr :
# [2025/12/17 10:29:13] ppocr INFO:         learning_rate : 0.0001
# [2025/12/17 10:29:13] ppocr INFO:         name : Cosine
# [2025/12/17 10:29:13] ppocr INFO:         warmup_epoch : 5
# [2025/12/17 10:29:13] ppocr INFO:     name : Adam
# [2025/12/17 10:29:13] ppocr INFO:     regularizer :
# [2025/12/17 10:29:13] ppocr INFO:         factor : 3e-05
# [2025/12/17 10:29:13] ppocr INFO:         name : L2
# [2025/12/17 10:29:13] ppocr INFO: PostProcess :
# [2025/12/17 10:29:13] ppocr INFO:     name : CTCLabelDecode
# [2025/12/17 10:29:13] ppocr INFO: Train :
# [2025/12/17 10:29:13] ppocr INFO:     dataset :
# [2025/12/17 10:29:13] ppocr INFO:         data_dir : ./train_data/rec
# [2025/12/17 10:29:13] ppocr INFO:         ds_width : False
# [2025/12/17 10:29:13] ppocr INFO:         ext_op_transform_idx : 1
# [2025/12/17 10:29:13] ppocr INFO:         label_file_list : ['./train_data/rec/rec_gt_train.txt']
# [2025/12/17 10:29:13] ppocr INFO:         name : MultiScaleDataSet
# [2025/12/17 10:29:13] ppocr INFO:         transforms :
# [2025/12/17 10:29:13] ppocr INFO:             DecodeImage :
# [2025/12/17 10:29:13] ppocr INFO:                 channel_first : False
# [2025/12/17 10:29:13] ppocr INFO:                 img_mode : BGR
# [2025/12/17 10:29:13] ppocr INFO:             RecConAug :
# [2025/12/17 10:29:13] ppocr INFO:                 ext_data_num : 2
# [2025/12/17 10:29:13] ppocr INFO:                 image_shape : [48, 320, 3]
# [2025/12/17 10:29:13] ppocr INFO:                 max_text_length : 25
# [2025/12/17 10:29:13] ppocr INFO:                 prob : 0.5
# [2025/12/17 10:29:13] ppocr INFO:             RecAug : None
# [2025/12/17 10:29:13] ppocr INFO:             MultiLabelEncode :
# [2025/12/17 10:29:13] ppocr INFO:                 gtc_encode : NRTRLabelEncode
# [2025/12/17 10:29:13] ppocr INFO:             KeepKeys :
# [2025/12/17 10:29:13] ppocr INFO:                 keep_keys : ['image', 'label_ctc', 'label_gtc', 'length', 'valid_ratio']
# [2025/12/17 10:29:13] ppocr INFO:     loader :
# [2025/12/17 10:29:13] ppocr INFO:         batch_size_per_card : 128
# [2025/12/17 10:29:13] ppocr INFO:         drop_last : True
# [2025/12/17 10:29:13] ppocr INFO:         num_workers : 8
# [2025/12/17 10:29:13] ppocr INFO:         shuffle : True
# [2025/12/17 10:29:13] ppocr INFO:     sampler :
# [2025/12/17 10:29:13] ppocr INFO:         divided_factor : [8, 16]
# [2025/12/17 10:29:13] ppocr INFO:         first_bs : 128
# [2025/12/17 10:29:13] ppocr INFO:         fix_bs : False
# [2025/12/17 10:29:13] ppocr INFO:         is_training : True
# [2025/12/17 10:29:13] ppocr INFO:         name : MultiScaleSampler
# [2025/12/17 10:29:13] ppocr INFO:         scales : [[320, 32], [320, 48], [320, 64]]
# [2025/12/17 10:29:13] ppocr INFO: profiler_options : None
# [2025/12/17 10:29:13] ppocr INFO: train with paddle 3.2.2 and device Place(gpu:0)
# [2025/12/17 10:29:13] ppocr INFO: Initialize indexes of datasets:['./train_data/rec/rec_gt_val.txt']
# [2025/12/17 10:29:14] ppocr INFO: load pretrain successful from ./output/th_rec_finetune/iter_epoch_20
# [2025/12/17 10:29:14] ppocr INFO: metric in ckpt ***************
# [2025/12/17 10:29:14] ppocr INFO: is_float16:False
# [2025/12/17 10:29:18] ppocr INFO: metric eval ***************
# [2025/12/17 10:29:18] ppocr INFO: acc:0.14062498901367274
# [2025/12/17 10:29:18] ppocr INFO: norm_edit_dis:0.6109397380998131
# [2025/12/17 10:29:18] ppocr INFO: fps:33.482373746401024
#
#
# ===== STDERR (tail) =====
# /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages/paddle/utils/cpp_extension/extension_utils.py:718: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# W1217 10:29:13.553922 14758 gpu_resources.cc:114] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 13.0, Runtime API Version: 12.6
#
# eval model::   0%|          | 0/128 [00:00<?, ?it/s]
# eval model::   1%|          | 1/128 [00:00<00:56,  2.27it/s]
# eval model::   4%|▍         | 5/128 [00:00<00:11, 11.18it/s]
# eval model::   7%|▋         | 9/128 [00:00<00:06, 18.04it/s]
# eval model::  10%|█         | 13/128 [00:00<00:04, 23.26it/s]
# eval model::  13%|█▎        | 17/128 [00:00<00:04, 27.12it/s]
# eval model::  16%|█▋        | 21/128 [00:00<00:03, 29.77it/s]
# eval model::  20%|█▉        | 25/128 [00:01<00:03, 31.68it/s]
# eval model::  23%|██▎       | 29/128 [00:01<00:03, 32.97it/s]
# eval model::  26%|██▌       | 33/128 [00:01<00:02, 33.85it/s]
# eval model::  29%|██▉       | 37/128 [00:01<00:02, 34.49it/s]
# eval model::  32%|███▏      | 41/128 [00:01<00:02, 33.93it/s]
# eval model::  35%|███▌      | 45/128 [00:01<00:02, 34.45it/s]
# eval model::  38%|███▊      | 49/128 [00:01<00:02, 34.71it/s]
# eval model::  41%|████▏     | 53/128 [00:01<00:02, 35.12it/s]
# eval model::  45%|████▍     | 57/128 [00:02<00:02, 35.26it/s]
# eval model::  48%|████▊     | 61/128 [00:02<00:01, 35.73it/s]
# eval model::  51%|█████     | 65/128 [00:02<00:01, 36.14it/s]
# eval model::  54%|█████▍    | 69/128 [00:02<00:01, 36.26it/s]
# eval model::  57%|█████▋    | 73/128 [00:02<00:01, 36.38it/s]
# eval model::  60%|██████    | 77/128 [00:02<00:01, 36.28it/s]
# eval model::  63%|██████▎   | 81/128 [00:02<00:01, 36.26it/s]
# eval model::  66%|██████▋   | 85/128 [00:02<00:01, 35.93it/s]
# eval model::  70%|██████▉   | 89/128 [00:02<00:01, 35.80it/s]
# eval model::  73%|███████▎  | 93/128 [00:03<00:00, 35.69it/s]
# eval model::  76%|███████▌  | 97/128 [00:03<00:00, 35.76it/s]
# eval model::  79%|███████▉  | 101/128 [00:03<00:00, 35.69it/s]
# eval model::  82%|████████▏ | 105/128 [00:03<00:00, 35.66it/s]
# eval model::  85%|████████▌ | 109/128 [00:03<00:00, 35.74it/s]
# eval model::  88%|████████▊ | 113/128 [00:03<00:00, 35.65it/s]
# eval model::  91%|█████████▏| 117/128 [00:03<00:00, 35.85it/s]
# eval model::  95%|█████████▍| 121/128 [00:03<00:00, 36.23it/s]
# eval model::  98%|█████████▊| 125/128 [00:03<00:00, 36.80it/s]
# eval model:: 100%|██████████| 128/128 [00:03<00:00, 32.10it/s]

# %%
import os, sys, subprocess

best = r"./output/th_rec_finetune/iter_epoch_20.pdparams"

cmd = [
    sys.executable, "tools/export_model.py",
    "-c", "configs/rec/my_th_rec_finetune.yaml",
    "-o",
    f"Global.pretrained_model={best}",
    "Global.save_inference_dir=./inference/th_rec_finetune"]


p = subprocess.run(cmd, text=True ,capture_output=True)

print("returncode =", p.returncode)
print("\n===== STDOUT (tail) =====")
print(p.stdout[-4000:])
print("\n===== STDERR (tail) =====")
print(p.stderr[-4000:])
# Out:
# returncode = 0
#
# ===== STDOUT (tail) =====
# Skipping import of the encryption module.
# [2025/12/17 10:33:13] ppocr INFO: load pretrain successful from ./output/th_rec_finetune/iter_epoch_20
# [2025/12/17 10:33:13] ppocr INFO: Export inference config file to ./inference/th_rec_finetune/inference.yml
# Skipping import of the encryption module
# [2025/12/17 10:33:16] ppocr INFO: inference model is saved to ./inference/th_rec_finetune/inference
#
#
# ===== STDERR (tail) =====
# /home/sagemaker-user/.conda/envs/data_science_on_aws/lib/python3.12/site-packages/paddle/utils/cpp_extension/extension_utils.py:718: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# W1217 10:33:12.769980 15205 gpu_resources.cc:114] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 13.0, Runtime API Version: 12.6
# W1217 10:33:14.638943 15205 eager_utils.cc:3441] Paddle static graph(PIR) not support input out tensor for now!!!!!
